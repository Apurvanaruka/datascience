# %%
import pyautogui
# import time

# def write_text_to_cursor(text_file):
#   """Writes the contents of the text file to the cursor's current position.

#   Args:
#     text_file: The path to the text file to be written.
#   """

#   with open(text_file, 'r') as f:
#     text = f.read()

#   pyautogui.typewrite(text)

# if __name__ == '__main__':
#   text_file = input('Enter the path to the text file: ')
#   write_text_to_cursor(text_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/apurvanaruka/snap/jupyter/common/lib/python3.7/site-packages/Xlib/support/unix_connect.py in get_socket(dname, host, dno)
#      75             s = socket.socket(socket.AF_UNIX, socket.SOCK_STREAM)
# ---> 76             s.connect('/tmp/.X11-unix/X%d' % dno)
#      77     except OSError as val:
#
# FileNotFoundError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DisplayConnectionError                    Traceback (most recent call last)
# <ipython-input-1-280094e9a766> in <module>
# ----> 1 import pyautogui
#       2 # import time
#       3
#       4 # def write_text_to_cursor(text_file):
#       5 #   """Writes the contents of the text file to the cursor's current position.
#
# ...

# %%
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 497.3 kB/s eta 0:00:00 kB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.2/168.2 kB 1.2 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
